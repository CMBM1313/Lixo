# %% [markdown]
# <a href="https://colab.research.google.com/github/CMBM1313/Lixo/blob/Leitor-de-voz/Prototipo_de_leitore_de_voz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import speech_recognition as sr

# Path to the audio file
audio_path = '/mnt/data/WhatsApp Ptt 2024-11-14 at 21.32.04.ogg'

# Initialize recognizer class (for recognizing the speech)
recognizer = sr.Recognizer()

# Load audio file and convert it to text
with sr.AudioFile(audio_path) as source:
    audio_data = recognizer.record(source)
    try:
        # Recognize speech using Google Web Speech API
        text = recognizer.recognize_google(audio_data, language='pt-BR')
    except sr.UnknownValueError:
        text = "Não foi possível entender o áudio."
    except sr.RequestError:
        text = "Erro na requisição do serviço de reconhecimento de fala."

text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a1054268200b> in <cell line: 1>()
# ----> 1 import speech_recognition as sr
#       2
#       3 # Path to the audio file
#       4 audio_path = '/mnt/data/WhatsApp Ptt 2024-11-14 at 21.32.04.ogg'
#       5
#
# ModuleNotFoundError: No module named 'speech_recognition'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
